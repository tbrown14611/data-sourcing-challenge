# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
def get_url(ak, bd, ed, fq, fl, so):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key="+ak+"&begin_date="+bd+"&end_date="+ed+"&fq="+fq+"so"+so+"&fl="+fl
    return url

# %%
# Set the base URL
#url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
#filter_query = 'Movies'
# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

url = get_url(nyt_api_key,begin_date,end_date,filter_query,field_list,sort)
#print(url)

# %%
# Create an empty list to store the review
reviews_list = []
#url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=MebDfltQAgwkMaU61WR9BEXzAUB6W3fq&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count'
# loop through pages 0-19
for page in range(20):
    # create query with page number
    query_url = f"{url}&page={str(page)}"
    reviews = requests.get(query_url).json()
    time. sleep(12)
    for review in reviews["response"]["docs"]:
        # Try and save the reviews to the reviews_list
            try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        # Print the page that was just retrieved
                print(f"Checked Page: {page}")
                #print(reviews)
                reviews_list.append(review)
            except:
        #Print the page number that had no results then break from the loop
                print(f"No Results found for page: {page}")
            break
# Out:
# Checked Page: 0
# Checked Page: 1
# Checked Page: 2
# Checked Page: 3
# Checked Page: 4
# Checked Page: 5
# Checked Page: 6
# Checked Page: 7
# Checked Page: 8
# Checked Page: 9
# Checked Page: 10
# Checked Page: 11
# Checked Page: 12
# Checked Page: 13
# Checked Page: 14
# Checked Page: 15
# Checked Page: 16
# Checked Page: 17
# Checked Page: 18
# Checked Page: 19

# %%
for review in reviews_list:
    print(f'A snippet from the review: {review["snippet"]}')
    print('---------------------------')
# Out:
# A snippet from the review: The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.
# ---------------------------
# A snippet from the review: Morgan Neville’s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of “The Other Side of the Wind.”
# ---------------------------
# A snippet from the review: Sharon Shattuck’s documentary tells her family story of growing up with a transgender parent.
# ---------------------------
# A snippet from the review: Drawn from the plotline of a Todd Snider song, the film follows a pool shark and an escort, taking twists that are both violent and silly.
# ---------------------------
# A snippet from the review: It’s hard to find a reliable, talented, reasonably priced, eco-friendly contractor these days.
# ---------------------------
# A snippet from the review: This superficial take on the writing and initial staging of “Cyrano de Bergerac” is a whirlwind of soapy declarations and backstage chaos.
# ---------------------------
# A snippet from the review: A gas station looms large in “Detroit Unleaded,” a soft-spoken Arab-American romantic comedy.
# ---------------------------
# A snippet from the review: Haley Lu Richardson and Cole Sprouse navigate the rules of attraction and of a hospital in this film about living with cystic fibrosis.
# ---------------------------
# A snippet from the review: This comedy is a daddy-issues movie with a queasy premise truly made for these times.
# ---------------------------
# A snippet from the review: The Japanese director Ryusuke Hamaguchi follows up his marathon “Happy Hour” with a story of love among young urbanites.
# ---------------------------
# A snippet from the review: Kate Winslet’s fossil hunter and Saoirse Ronan’s convalescent embark on a forbidden seaside romance.
# ---------------------------
# A snippet from the review: Thomas Mann’s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.
# ---------------------------
# A snippet from the review: A couple’s reception becomes a disaster (or does it?) in this comedy of multiple errors.
# ---------------------------
# A snippet from the review: This feature debut of the writer and director Francis Lee is a bracing, sometimes brutal movie.
# ---------------------------
# A snippet from the review: An intimate, affecting film about a couple with autism, as they plan their wedding.
# ---------------------------
# A snippet from the review: When a perennially single journalist travels across the country to meet her dream guy, she finds she’s been catfished.
# ---------------------------
# A snippet from the review: The rise and fall of the provocative rapper Tekashi69 is chronicled in this Hulu documentary.
# ---------------------------
# A snippet from the review: In Kike Maíllo’s Spanish drama, a prodigy returns to his hometown to work on programming an android with the emotional life of a real child.
# ---------------------------
# A snippet from the review: This joyous documentary follows the Preservation Hall Jazz Band to Cuba for a celebration of musical history and common bonds.
# ---------------------------
# A snippet from the review: A Paris illustrator tries to win back his ex-girlfriend through unorthodox means in “The Stroller Strategy,” directed by Clément Michel.
# ---------------------------

# %%
# json.dumps with the argument indent=4 is used to preview the first five results

print(json.dumps(reviews_list, indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html",
#         "snippet": "The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Kangaroo: A Love-Hate Story\u2019 Exposes a Wildlife Massacre",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Kangaroo: A Love-Hate Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Kangaroo: A Love-Hate Story (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Kangaroos",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Animal Abuse, Rights and Welfare",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre Clere, Kate",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre, Mick",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Australia",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-01-18T12:00:23+0000",
#         "byline": {
#             "original": "By Ken Jaworowski",
#             "person": [
#                 {
#                     "firstname": "Ken",
#                     "middlename": null,
#                     "lastname": "Jaworowski",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 263
#     },
#     {
#         "web_url": "https://www.nytimes.com/2018/11/01/movies/theyll-love-me-when-im-dead-review-documentary.html",
#         "snippet": "Morgan Neville\u2019s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of \u201cThe Other Side of the Wind.\u201d",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018They\u2019ll Love Me When I\u2019m Dead\u2019 Documents Orson Welles\u2019s Last Film",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Legend Behind The Scenes",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "They'll Love Me When I'm Dead (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Neville, Morgan",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Other Side of the Wind (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Welles, Orson",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-11-01T13:56:39+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 794
#     },
#     {
#         "web_url": "https://www.nytimes.com/2016/06/24/movies/from-this-day-forward-review.html",
#         "snippet": "Sharon Shattuck\u2019s documentary tells her family story of growing up with a transgender parent.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018From This Day Forward\u2019 Attests to Love\u2019s Adaptability",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: \u2018From This Day Forward\u2019 Attests to Love\u2019s Adaptability",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Shattuck, Sharon",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Transgender and Transsexuals",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2016-06-23T21:11:31+0000",
#         "byline": {
#             "original": "By Andy Webster",
#             "person": [
#                 {
#                     "firstname": "Andy",
#                     "middlename": null,
#                     "lastname": "Webster",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 252
#     },
#     {
#         "web_url": "https://www.nytimes.com/2021/10/14/movies/hard-luck-love-song-review.html",
#         "snippet": "Drawn from the plotline of a Todd Snider song, the film follows a pool shark and an escort, taking twists that are both violent and silly.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Hard Luck Love Song\u2019 Review: A Glossy Take on a Gritty Tune",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Hard Luck Love Song",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Dorman, Michael (1981- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Hard Luck Love Song (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bush, Sophia (1982- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2021-10-14T12:27:03+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 320
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/08/29/movies/falling-inn-love-review.html",
#         "snippet": "It\u2019s hard to find a reliable, talented, reasonably priced, eco-friendly contractor these days.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Falling Inn Love\u2019 Review: A Prize That Needs Some Work",
#             "kicker": "Streaming Movie Review",
#             "content_kicker": null,
#             "print_headline": "A Fine Romance to Watch While Sorting Socks",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Netflix Inc",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kumble, Roger",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Milian, Christina",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Demos, Adam",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Falling Inn Love (Movie)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-08-29T14:56:44+0000",
#         "byline": {
#             "original": "By Helen T. Verongos",
#             "person": [
#                 {
#                     "firstname": "Helen",
#                     "middlename": "T.",
#                     "lastname": "Verongos",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 374
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/10/17/movies/cyrano-my-love-review.html",
#         "snippet": "This superficial take on the writing and initial staging of \u201cCyrano de Bergerac\u201d is a whirlwind of soapy declarations and backstage chaos.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Cyrano, My Love\u2019 Review: A Nose for Romance",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Cyrano, My Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Cyrano, My Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Michalik, Alexis",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-10-17T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 291
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/11/22/movies/detroit-unleaded-a-low-octane-comedy.html",
#         "snippet": "A gas station looms large in \u201cDetroit Unleaded,\u201d a soft-spoken Arab-American romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love Among the Gas Pumps",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Detroit Unleaded",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Detroit Unleaded (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Nashef, Rola",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Shouhayib, Nada",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Assi, E J",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-11-21T23:52:02+0000",
#         "byline": {
#             "original": "By Neil Genzlinger",
#             "person": [
#                 {
#                     "firstname": "Neil",
#                     "middlename": null,
#                     "lastname": "Genzlinger",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 237
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/03/14/movies/five-feet-apart-review.html",
#         "snippet": "Haley Lu Richardson and Cole Sprouse navigate the rules of attraction and of a hospital in this film about living with cystic fibrosis.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Five Feet Apart\u2019 Review: Ailing Teenagers Live Dangerously for Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Five Feet Apart",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Five Feet Apart (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Baldoni, Justin",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-03-14T13:00:07+0000",
#         "byline": {
#             "original": "By Ben Kenigsberg",
#             "person": [
#                 {
#                     "firstname": "Ben",
#                     "middlename": null,
#                     "lastname": "Kenigsberg",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 258
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/08/04/movies/i-love-my-dad-review.html",
#         "snippet": "This comedy is a daddy-issues movie with a queasy premise truly made for these times.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018I Love My Dad\u2019 Review: A Father Catfishes His Son",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Father Catfishes His Son. We Just Wait for the Ick.",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Oswalt, Patton",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "I Love My Dad (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Morosini, James",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-08-04T11:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 418
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/05/16/movies/asako-i-and-ii-review.html",
#         "snippet": "The Japanese director Ryusuke Hamaguchi follows up his marathon \u201cHappy Hour\u201d with a story of love among young urbanites.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Asako I & II\u2019 Review: Double the Love (and the Heartbreak)",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Falling For a Drifter And His Lookalike",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Asako I & II (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hamaguchi, Ryusuke",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-05-16T11:00:01+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 547
#     },
#     {
#         "web_url": "https://www.nytimes.com/2020/11/12/movies/ammonite-review.html",
#         "snippet": "Kate Winslet\u2019s fossil hunter and Saoirse Ronan\u2019s convalescent embark on a forbidden seaside romance.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Ammonite\u2019 Review: Love on the Rocks",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Love on the Rocks",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ronan, Saoirse",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Winslet, Kate",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lee, Francis (1969- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Ammonite (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2020-11-12T12:00:04+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 510
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/09/08/movies/about-fate-review.html",
#         "snippet": "Thomas Mann\u2019s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018About Fate\u2019 Review: Love the One You\u2019re With?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "About Fate",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "About Fate (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Vaysberg, Marius",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mann, Thomas (1991- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Roberts, Emma (1991- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-09-09T01:00:03+0000",
#         "byline": {
#             "original": "By Lisa Kennedy",
#             "person": [
#                 {
#                     "firstname": "Lisa",
#                     "middlename": null,
#                     "lastname": "Kennedy",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 289
#     },
#     {
#         "web_url": "https://www.nytimes.com/2020/04/10/movies/love-wedding-repeat-review-a-tumble-down-the-aisle.html",
#         "snippet": "A couple\u2019s reception becomes a disaster (or does it?) in this comedy of multiple errors.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love Wedding Repeat\u2019 Review: A Tumble Down the Aisle",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Pratfalling Down The Aisle",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love Wedding Repeat (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Craig, Dean (1974- )",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Claflin, Sam",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Munn, Olivia",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2020-04-10T07:01:05+0000",
#         "byline": {
#             "original": "By Amy Nicholson",
#             "person": [
#                 {
#                     "firstname": "Amy",
#                     "middlename": null,
#                     "lastname": "Nicholson",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 414
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/10/24/movies/gods-own-country-review.html",
#         "snippet": "This feature debut of the writer and director Francis Lee is a bracing, sometimes brutal movie.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Love Is Wild, if Not Pretty, in \u2018God\u2019s Own Country\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love Is Wild, if Not Always Pretty",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "God's Own Country (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lee, Francis (1969- )",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Connor, Josh (Actor)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Secareanu, Alec",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-10-24T11:00:24+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/10/05/movies/dina-review.html",
#         "snippet": "An intimate, affecting film about a couple with autism, as they plan their wedding.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In the Documentary \u2018Dina,\u2019 a Differently Abled Love Story",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Dina",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Dina (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sickles, Dan (Film Director)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Santini, Antonio (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Autism",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-10-05T11:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 290
#     },
#     {
#         "web_url": "https://www.nytimes.com/2021/11/05/movies/love-hard-review.html",
#         "snippet": "When a perennially single journalist travels across the country to meet her dream guy, she finds she\u2019s been catfished.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love Hard\u2019 Review: Seeking Connection, Not Perfection",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love Hard",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love Hard (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Jimenez, Hernan",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2021-11-05T07:01:03+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 343
#     },
#     {
#         "web_url": "https://www.nytimes.com/2020/11/17/movies/69-saga-of-danny-hernadez-review.html",
#         "snippet": "The rise and fall of the provocative rapper Tekashi69 is chronicled in this Hulu documentary.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u201869: The Saga of Danny Hernandez\u2019 Review: A SoundCloud-Rap Rat",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Loved in Hip-Hop, but Loathed in the End",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Rap and Hip-Hop",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gandhi, Vikram",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "6ix9ine (Rapper)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "69: The Saga of Danny Hernandez (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2020-11-17T19:07:20+0000",
#         "byline": {
#             "original": "By Calum Marsh",
#             "person": [
#                 {
#                     "firstname": "Calum",
#                     "middlename": null,
#                     "lastname": "Marsh",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 363
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/03/13/movies/review-in-eva-robot-designer-loves-cute-kid.html",
#         "snippet": "In Kike Ma\u00edllo\u2019s Spanish drama, a prodigy returns to his hometown to work on programming an android with the emotional life of a real child.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In \u2018Eva,\u2019 Robot Designer Loves Cute Kid",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "In \u2018Eva,\u2019 Robot Designer Loves Cute Kid",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Maillo, Kike",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Eva (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2015-03-13T02:39:35+0000",
#         "byline": {
#             "original": "By Neil Genzlinger",
#             "person": [
#                 {
#                     "firstname": "Neil",
#                     "middlename": null,
#                     "lastname": "Genzlinger",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 216
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/02/14/movies/a-tuba-to-cuba-review.html",
#         "snippet": "This joyous documentary follows the Preservation Hall Jazz Band to Cuba for a celebration of musical history and common bonds.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tuba to Cuba\u2019 Review: A New Orleans Jazz Band Makes a Caribbean Connection",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Love Notes Forge a Caribbean Bond",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tuba to Cuba (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Herrington, TG",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Clinch, Danny",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Jazz",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Preservation Hall Jazz Band",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-02-14T12:00:01+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 267
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/06/14/movies/the-stroller-strategy-a-french-comedy.html",
#         "snippet": "A Paris illustrator tries to win back his ex-girlfriend through unorthodox means in \u201cThe Stroller Strategy,\u201d directed by Cl\u00e9ment Michel.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Solution to His Love Problems?: Baby Formula",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "The Stroller Strategy",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Michel, Clement",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-06-14T02:20:57+0000",
#         "byline": {
#             "original": "By Nicolas Rapold",
#             "person": [
#                 {
#                     "firstname": "Nicolas",
#                     "middlename": null,
#                     "lastname": "Rapold",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 223
#     }
# ]

# %%
# Convert the results to a DataFrame, normalizing the JSON
nyt_df = pd.json_normalize(reviews_list)
nyt_df.head(5)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2018/01/18/movies/kang...
# 1  https://www.nytimes.com/2018/11/01/movies/they...
# 2  https://www.nytimes.com/2016/06/24/movies/from...
# 3  https://www.nytimes.com/2021/10/14/movies/hard...
# 4  https://www.nytimes.com/2019/08/29/movies/fall...
#
#                                              snippet              source  \
# 0  The documentary looks at the mass killings of ...  The New York Times
# 1  Morgan Neville’s movie tells the tumultuous be...  The New York Times
# 2  Sharon Shattuck’s documentary tells her family...  The New York Times
# 3  Drawn from the plotline of a Todd Snider song,...  The New York Times
# 4  It’s hard to find a reliable, talented, reason...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'creative_works', 'value': 'Kangaroo...
# 1  [{'name': 'subject', 'value': 'Documentary Fil...
# 2  [{'name': 'subject', 'value': 'Documentary Fil...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2018-01-18T12:00:23+0000         263
# 1  2018-11-01T13:56:39+0000         794
# 2  2016-06-23T21:11:31+0000         252
# 3  2021-10-14T12:27:03+0000         320
# 4  2019-08-29T14:56:44+0000         374
#
#                                        headline.main         headline.kicker  \
# 0  Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...                    None
# 1  Review: ‘They’ll Love Me When I’m Dead’ Docume...                    None
# 2  Review: ‘From This Day Forward’ Attests to Lov...                    None
# 3  ‘Hard Luck Love Song’ Review: A Glossy Take on...                    None
# 4  ‘Falling Inn Love’ Review: A Prize That Needs ...  Streaming Movie Review
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None                        Kangaroo: A Love-Hate Story
# 1                    None                       The Legend Behind The Scenes
# 2                    None  Review: ‘From This Day Forward’ Attests to Lov...
# 3                    None                                Hard Luck Love Song
# 4                    None        A Fine Romance to Watch While Sorting Socks
#
#   headline.name headline.seo headline.sub       byline.original  \
# 0          None         None         None     By Ken Jaworowski
# 1          None         None         None     By Manohla Dargis
# 2          None         None         None       By Andy Webster
# 3          None         None         None        By Glenn Kenny
# 4          None         None         None  By Helen T. Verongos
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 1  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 2  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Helen', 'middlename': 'T.', 'l...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019.
# End string should include " Review" to avoid cutting title early

nyt_df['title'] = nyt_df['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
nyt_df['title']
# Out:
# 0     Kangaroo: A Love-Hate Story’ Exposes a Wildlif...
# 1     They’ll Love Me When I’m Dead’ Documents Orson...
# 2     From This Day Forward’ Attests to Love’s Adapt...
# 3                                   Hard Luck Love Song
# 4                                      Falling Inn Love
# 5                                       Cyrano, My Love
# 6                               Love Among the Gas Pump
# 7                                       Five Feet Apart
# 8                                         I Love My Dad
# 9                                          Asako I & II
# 10                                             Ammonite
# 11                                           About Fate
# 12                                  Love Wedding Repeat
# 13                                    God’s Own Country
# 14                 Dina,’ a Differently Abled Love Stor
# 15                                            Love Hard
# 16                      69: The Saga of Danny Hernandez
# 17                   Eva,’ Robot Designer Loves Cute Ki
# 18                                       A Tuba to Cuba
# 19          Solution to His Love Problems?: Baby Formul
# Name: title, dtype: object

# %%
# Extract 'name' and 'value' from items in "keywords" column

def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
nyt_df['keywords'] =  nyt_df['keywords'].apply(extract_keywords) 
nyt_df['keywords']
# Out:
# 0     creative_works: Kangaroo: A Love-Hate Story (M...
# 1     subject: Documentary Films and Programs;creati...
# 2     subject: Documentary Films and Programs;person...
# 3     subject: Movies;persons: Dorman, Michael (1981...
# 4     subject: Movies;organizations: Netflix Inc;per...
# 5     subject: Movies;creative_works: Cyrano, My Lov...
# 6     subject: Movies;creative_works: Detroit Unlead...
# 7     subject: Movies;creative_works: Five Feet Apar...
# 8     subject: Movies;persons: Oswalt, Patton;creati...
# 9     subject: Movies;creative_works: Asako I & II (...
# 10    subject: Movies;persons: Ronan, Saoirse;person...
# 11    subject: Movies;creative_works: About Fate (Mo...
# 12    subject: Movies;creative_works: Love Wedding R...
# 13    subject: Movies;creative_works: God's Own Coun...
# 14    creative_works: Dina (Movie);subject: Document...
# 15    subject: Movies;creative_works: Love Hard (Mov...
# 16    subject: Documentary Films and Programs;subjec...
# 17    subject: Movies;persons: Maillo, Kike;creative...
# 18    subject: Documentary Films and Programs;creati...
# 19            subject: Movies;persons: Michel, Clement;
# Name: keywords, dtype: object

# %%
# Create a list from the "title" column using to_list()
title_list = []
title_list = nyt_df['title'].tolist()
# These titles will be used in the query for The Movie Database

title_list
# Out:
# ['Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
#  'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
#  'From This Day Forward’ Attests to Love’s Adaptabilit',
#  'Hard Luck Love Song',
#  'Falling Inn Love',
#  'Cyrano, My Love',
#  'Love Among the Gas Pump',
#  'Five Feet Apart',
#  'I Love My Dad',
#  'Asako I & II',
#  'Ammonite',
#  'About Fate',
#  'Love Wedding Repeat',
#  'God’s Own Country',
#  'Dina,’ a Differently Abled Love Stor',
#  'Love Hard',
#  '69: The Saga of Danny Hernandez',
#  'Eva,’ Robot Designer Loves Cute Ki',
#  'A Tuba to Cuba',
#  'Solution to His Love Problems?: Baby Formul']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie/11"
tmdb_key_string = "?api_key=" + tmdb_api_key

url = f"https://api.themoviedb.org/3/search/movie{tmdb_key_string}&include_adult=false&language=en-US&page=1"

print(url)
# Out:
# https://api.themoviedb.org/3/search/movie?api_key=edd86bc79f18410743b10d55284de412&include_adult=false&language=en-US&page=1

# %%
# Create an empty tmdb_movies_list list to store the results
# and Add the relevant data to it.
# Empty list for results
movie_id_list = []  
tmdb_movies_list = []
tmdb_movies_list_details = []
results_list = []
genre_list = []
genre_row_list = []
unique_genre_names = []
spoken_languages_list = []
unique_spoken_languages_names = []
production_countries_list = []
unique_production_countries_names = []
details_dictionary = {}
details_results_list = []
request_counter = 0
title_found_counter = 0
# loop through the title_list
    # Loop through the titles
for title in title_list:
    # Set up the query
    query_url = f"{url}&query={title}"
    #print(query_url)
    # Perform a "GET" request for The Movie Database
    results = requests.get(query_url).json()
    if results['total_results'] > 0:
        #print(json.dumps(results, indent=4))
        # Print out the title that was found
        title_found_counter += 1
        print(f"Found {results['total_results']} result(s) for {title} counter: {title_found_counter}")
        # add id and title to filtered_data
        for result in results["results"]:
            if result["id"] not in movie_id_list:
                movie_id_list.append(result["id"])
                tmdb_movies_list.append(result)
                print(f'Found id: {result["id"]} for {title}')
    else:
         print(f"NOT Found {results['total_results']} result(s) for {title}")
    # Check if we need to sleep before making a request 
    # Add 1 to the request counter
    request_counter += 1
    #print(f"Request Counter: {request_counter%50}")
    if request_counter%50 == 0:
        print("sleeping")
    # Add a 12 second interval between queries to stay within API query limits
        time.sleep(12)
# Include a try clause to search for the full movie details.
pop_movie_id_list = movie_id_list.copy()
total_pop= len(movie_id_list)
for x in range(0, len(movie_id_list)):
    try:
        movie_id = pop_movie_id_list.pop()
        movie_id_str = str(movie_id)
    # Make a request for a the full movie details
    # Execute "GET" request with url  
        details_url ='https://api.themoviedb.org/3/movie/'+movie_id_str+tmdb_key_string
        #print(details_url)
        details_results = requests.get(details_url).json()
        tmdb_movies_list_details.append(details_results)
        #print(details_results)
         # Check if we need to sleep 
        # Add 1 to the request counter
        request_counter += 1
        #print(f"Request Counter: {request_counter%50}")
        if request_counter%50 == 0:
           print('sleeping')
        # Add a 12 second interval between queries to stay within API query limits
           time.sleep(12)
        # Use the except clause to print out a statement if a movie
        # is not found.
    except:
        print(f"Full movie details not found for id: {movie_id_list[x]} for {title}")
        continue
print(f'finished {total_pop} details for movies')
for details_results in tmdb_movies_list_details:
    # Extract the genre names into a list
    genre_list.append(details_results['genres'])
    # Extract the spoken_languages' English name into a list
    spoken_languages_list.append(details_results['spoken_languages'])   
    # Extract the production_countries' name into a list
    production_countries_list.append(details_results['production_countries'])
    details_results_dictionary = {
    'title':details_results['title'],
    'details_original_title':details_results['original_title'],
    'details_budget':details_results['budget'],
    'details_original_language':details_results['original_language'],
    'details_homepage':details_results['homepage'],
    'details_overview':details_results['overview'],
    'details_popularity':details_results['popularity'],
    'details_runtime':details_results['runtime'],
    'details_revenue':details_results['revenue'],
    'details_release_date':details_results['release_date'],
    'details_vote_average':details_results['vote_average'],
    'details_vote_count':details_results['vote_count'],
    'details_genre':details_results['genres'],
    'details_spoken_languages':details_results['spoken_languages'],
    'details_production_countries':details_results['production_countries']
    }
    details_results_list.append(details_results_dictionary)
#print(genre_list)
#print(spoken_languages_list)
#print(production_countries_list)    
for genre in genre_list:
    for item in genre:
        if(item['name'] not in unique_genre_names):
            unique_genre_names.append(item['name'])
print(f'unique_genre_names = {unique_genre_names}')
for spoken_language in spoken_languages_list:
    for item in spoken_language:
        if(item['english_name'] not in unique_spoken_languages_names):
            unique_spoken_languages_names.append(item['english_name'])
print(f'unique_spoken_languages_names = {unique_spoken_languages_names}')
for production_countries in production_countries_list:
    for item in production_countries:
        if(item['name'] not in unique_production_countries_names):
            unique_production_countries_names.append(item['name'])
print(f'unique_production_countries_names = {unique_production_countries_names}')
#print(json.dumps(details_results, indent=4))
# Add the relevant data to a dictionary 
details_dictionary["unique_genre_names"] = unique_genre_names
details_dictionary["unique_spoken_languages_names"] = unique_spoken_languages_names
details_dictionary["unique_production_countries_names"] = unique_production_countries_names
details_dictionary['details_results'] = details_results_list
print(f'details_dictonary = {details_dictionary}')
# append it to the tmdb_movies_list list
#tmdb_movies_list.append(details_dictionary)
# Out:
# NOT Found 0 result(s) for Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# NOT Found 0 result(s) for They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# NOT Found 0 result(s) for From This Day Forward’ Attests to Love’s Adaptabilit
# Found 1 result(s) for Hard Luck Love Song counter: 1
# Found id: 536208 for Hard Luck Love Song
# Found 1 result(s) for Falling Inn Love counter: 2
# Found id: 623195 for Falling Inn Love
# Found 2 result(s) for Cyrano, My Love counter: 3
# Found id: 544510 for Cyrano, My Love
# Found id: 445179 for Cyrano, My Love
# NOT Found 0 result(s) for Love Among the Gas Pump
# Found 1 result(s) for Five Feet Apart counter: 4
# Found id: 527641 for Five Feet Apart
# Found 3 result(s) for I Love My Dad counter: 5
# Found id: 876825 for I Love My Dad
# Found id: 1152894 for I Love My Dad
# Found id: 1239290 for I Love My Dad
# Found 1 result(s) for Asako I & II counter: 6
# Found id: 487850 for Asako I & II
# Found 3 result(s) for Ammonite counter: 7
# Found id: 568467 for Ammonite
# Found id: 1116655 for Ammonite
# Found id: 392170 for Ammonite
# Found 3 result(s) for About Fate counter: 8
# Found id: 828613 for About Fate
# Found id: 919068 for About Fate
# Found id: 41187 for About Fate
# Found 1 result(s) for Love Wedding Repeat counter: 9
# Found id: 624808 for Love Wedding Repeat
# Found 2 result(s) for God’s Own Country counter: 10
# Found id: 428493 for God’s Own Country
# Found id: 269820 for God’s Own Country
# NOT Found 0 result(s) for Dina,’ a Differently Abled Love Stor
# Found 23 result(s) for Love Hard counter: 11
# Found id: 734265 for Love Hard
# Found id: 552687 for Love Hard
# Found id: 252441 for Love Hard
# Found id: 833999 for Love Hard
# Found id: 39125 for Love Hard
# Found id: 419343 for Love Hard
# Found id: 1045374 for Love Hard
# Found id: 43846 for Love Hard
# Found id: 43483 for Love Hard
# Found id: 419370 for Love Hard
# Found id: 252306 for Love Hard
# Found id: 1155217 for Love Hard
# Found id: 8893 for Love Hard
# Found id: 287058 for Love Hard
# Found id: 48692 for Love Hard
# Found id: 252586 for Love Hard
# Found id: 86040 for Love Hard
# Found id: 441188 for Love Hard
# Found id: 1026127 for Love Hard
# Found 1 result(s) for 69: The Saga of Danny Hernandez counter: 12
# Found id: 765057 for 69: The Saga of Danny Hernandez
# NOT Found 0 result(s) for Eva,’ Robot Designer Loves Cute Ki
# Found 1 result(s) for A Tuba to Cuba counter: 13
# Found id: 502190 for A Tuba to Cuba
# NOT Found 0 result(s) for Solution to His Love Problems?: Baby Formul
# sleeping
# finished 39 details for movies
# unique_genre_names = ['Documentary', 'Music', 'History', 'Drama', 'TV Movie', 'Family', 'Comedy', 'Thriller', 'Romance', 'Crime', 'Horror']
# unique_spoken_languages_names = ['English', 'Japanese', 'Spanish', 'French', 'Portuguese', 'German', 'Russian', 'Mandarin', 'Malayalam', 'Romanian', 'Italian', 'Turkish']
# unique_production_countries_names = ['Cuba', 'United States of America', 'Japan', 'Mexico', 'Spain', 'France', 'Brazil', 'United Kingdom', 'Belgium', 'Germany', 'China', 'India', 'Italy', 'Turkey']
# details_dictonary = {'unique_genre_names': ['Documentary', 'Music', 'History', 'Drama', 'TV Movie', 'Family', 'Comedy', 'Thriller', 'Romance', 'Crime', 'Horror'], 'unique_spoken_languages_names': ['English', 'Japanese', 'Spanish', 'French', 'Portuguese', 'German', 'Russian', 'Mandarin', 'Malayalam', 'Romanian', 'Italian', 'Turkish'], 'unique_production_countries_names': ['Cuba', 'United States of America', 'Japan', 'Mexico', 'Spain', 'France', 'Brazil', 'United Kingdom', 'Belgium', 'Germany', 'China', 'India', 'Italy', 'Turkey'], 'details_results': [{'title': 'A Tuba To Cuba', 'details_original_title': 'A Tuba To Cuba', 'details_budget': 0, 'details_original_language': 'en', 'details_homepage': 'https://www.atubatocuba.com/', 'details_overview': 'A son seeking to fulfill his late father’s dream takes his band from the storied city of New Orleans to the shores of Cuba, where — through the universal language of music — dark and ancient connections between their peoples reveal the roots of jazz.', 'details_popularity': 2.244, 'details_runtime': 82, 'details_revenue': 0, 'details_release_date': '2019-02-15', 'details_vote_average': 6.6, 'details_vote_count': 8, 'details_genre': [{'id': 99, 'name': 'Documentary'}, {'id': 10402, 'name': 'Music'}, {'id': 36, 'name': 'History'}], 'details_spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'details_production_countries': [{'iso_3166_1': 'CU', 'name': 'Cuba'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]}, {'title': '69: The Saga of Danny Hernandez', 'details_original_title': '69: The Saga of Danny Hernandez', 'details_budget': 0, 'details_original_language': 'en', 'details_homepage': 'https://www.hulu.com/movie/69-the-saga-of-danny-hernandez-345025ec-5022-4cca-a5f7-d3870fce96b3', 'details_overview': 'Part investigative documentary, part real-life gangster movie, this film unpacks the life of polarizing rap sensation and internet troll Tekashi69, aka 69, while chronicling his meteoric rise and fall from fame.', 'details_popularity': 2.209, 'details_runtime': 101, 'details_revenue': 0, 'details_release_date': '2021-04-29', 'details_vote_average': 6.0, 'details_vote_count': 12, 'details_genre': [{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}], 'details_spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'details_production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}]}, {'title': 'Motto hageshiku motto tsuyoku', 'details_original_title': 'もっと激しくもっとつよく', 'details_budget': 0, 'details_original_language': 'ja', 'details_homepage': '', 'details_overview': '', 'details_popularity': 0.906, 'details_runtime': 74, 'details_revenue': 0, 'details_release_date': '1981-05-15', 'details_vote_average': 2.0, 'details_vote_count': 1, 'details_genre': [], 'details_spoken_languages': [{'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}], 'details_production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}]}, {'title': 'Chavela', 'details_original_title': 'Chavela', 'details_budget': 0, 'details_original_language': 'es', 'details_homepage': 'http://www.chavelavargasfilm.com/', 'details_overview': 'Inspired by an exclusive interview and performance footage of Chavela Vargas shot in 1991 and guided by her unique voice, the film weaves an arresting portrait of a woman who dared to dress, speak, sing, and dream her unique life into being.', 'details_popularity': 4.425, 'details_runtime': 93, 'details_revenue': 0, 'details_release_date': '2017-06-16', 'details_vote_average': 7.0, 'details_vote_count': 22, 'details_genre': [{'id': 99, 'name': 'Documentary'}], 'details_spoken_languages': [{'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'details_production_countries': [{'iso_3166_1': 'MX', 'name': 'Mexico'}, {'iso_3166_1': 'ES', 'name': 'Spain'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]}, {'title': 'To Sir, With Love II', 'details_origina ...

# %%
# Use json.dumps with argument indent=4 to format data

print(json.dumps(tmdb_movies_list, indent=4))
# Out:
# [
#     {
#         "adult": false,
#         "backdrop_path": "/l17qkQS5Goz1asb2Zs5LsopGIK3.jpg",
#         "genre_ids": [
#             10749,
#             10402,
#             18,
#             53
#         ],
#         "id": 536208,
#         "original_language": "en",
#         "original_title": "Hard Luck Love Song",
#         "overview": "Jesse, a charismatic but down on his luck troubadour, finds himself at an existential crossroads as bad choices catch up with him during an unexpected reunion with Carla, an old flame.",
#         "popularity": 3.851,
#         "poster_path": "/fWUbYGT0zTJoEZVyc2SvsenoHPF.jpg",
#         "release_date": "2021-10-15",
#         "title": "Hard Luck Love Song",
#         "video": false,
#         "vote_average": 4.9,
#         "vote_count": 10
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/lVJdFZc8hBJRVnOIay60tl04Qjv.jpg",
#         "genre_ids": [
#             10749,
#             35
#         ],
#         "id": 623195,
#         "original_language": "en",
#         "original_title": "Falling Inn Love",
#         "overview": "When a San Francisco exec wins a New Zealand inn, she ditches city life to remodel and flip the rustic property with help from a handsome contractor.",
#         "popularity": 17.92,
#         "poster_path": "/4bzu5k5vwLKgwap6pHXlCY8nlh3.jpg",
#         "release_date": "2019-08-29",
#         "title": "Falling Inn Love",
#         "video": false,
#         "vote_average": 6.5,
#         "vote_count": 1114
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/dn7wTIud3Yroopm8bWN8WtidTBW.jpg",
#         "genre_ids": [
#             35,
#             36
#         ],
#         "id": 544510,
#         "original_language": "fr",
#         "original_title": "Edmond",
#         "overview": "Paris, France, December 1897. The young playwright Edmond Rostand feels like a failure. Inspiration has abandoned him. Married and father of two children, desperate and penniless, he persuades the great actor Constant Coquelin to perform the main role in his new play. But there is a problem: Coquelin wants to premiere it at Christmas and Edmond has not written a single word.",
#         "popularity": 11.72,
#         "poster_path": "/9Y1VxSfJdu8fqQqgX0x6OObxvUw.jpg",
#         "release_date": "2018-11-10",
#         "title": "Cyrano, My Love",
#         "video": false,
#         "vote_average": 7.5,
#         "vote_count": 476
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/uRJb4Ukin4pQeTuyv07TqsBQt72.jpg",
#         "genre_ids": [
#             10749
#         ],
#         "id": 445179,
#         "original_language": "ja",
#         "original_title": "\u308f\u305f\u3057\u306b\u904b\u547d\u306e\u604b\u306a\u3093\u3066\u3042\u308a\u3048\u306a\u3044\u3063\u3066\u601d\u3063\u3066\u305f",
#         "overview": "Riko is 27, working as a love simulation game designer, and she no longer has big expectations for a man in her life. One day app company TIMEIS, lead by Soichiro, hires her to work on their latest game.",
#         "popularity": 7.34,
#         "poster_path": "/nBrixx0zRnOufOaK9oVBUGlTS5f.jpg",
#         "release_date": "2017-12-23",
#         "title": "My Long Awaited Love Story",
#         "video": false,
#         "vote_average": 8.1,
#         "vote_count": 5
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/27ZkYMWynuK2qiDP6awc3MsCaOs.jpg",
#         "genre_ids": [
#             10749,
#             18
#         ],
#         "id": 527641,
#         "original_language": "en",
#         "original_title": "Five Feet Apart",
#         "overview": "Seventeen-year-old Stella spends most of her time in the hospital as a cystic fibrosis patient. Her life is full of routines, boundaries and self-control \u2014 all of which get put to the test when she meets Will, an impossibly charming teen who has the same illness. There's an instant flirtation, though restrictions dictate that they must maintain a safe distance between them. As their connection intensifies, so does the temptation to throw the rules out the window and embrace that attraction.",
#         "popularity": 56.515,
#         "poster_path": "/kreTuJBkUjVWePRfhHZuYfhNE1T.jpg",
#         "release_date": "2019-03-14",
#         "title": "Five Feet Apart",
#         "video": false,
#         "vote_average": 8.271,
#         "vote_count": 5395
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/3X4t5Zzbd05dG5xtehC3mI0qImX.jpg",
#         "genre_ids": [
#             35
#         ],
#         "id": 876825,
#         "original_language": "en",
#         "original_title": "I Love My Dad",
#         "overview": "A hopelessly estranged father catfishes his son in an attempt to reconnect.",
#         "popularity": 8.4,
#         "poster_path": "/fTP28OF0SlRRyng0QX3ekzCPFgW.jpg",
#         "release_date": "2022-08-05",
#         "title": "I Love My Dad",
#         "video": false,
#         "vote_average": 5.8,
#         "vote_count": 42
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/l4FDE6ZhpwE8Ma4r9IxmsKPwn6v.jpg",
#         "genre_ids": [
#             27
#         ],
#         "id": 1152894,
#         "original_language": "en",
#         "original_title": "i love my dad",
#         "overview": "Brandon Daily makes a vlog about his relationship with his dad.",
#         "popularity": 0.665,
#         "poster_path": "/wd3ZYMkAo2UrkksFKTHLEjWqU5n.jpg",
#         "release_date": "2023-07-14",
#         "title": "i love my dad",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/1sWKjAY99LixIRgwkIDHheR0cgB.jpg",
#         "genre_ids": [
#             99,
#             18
#         ],
#         "id": 1239290,
#         "original_language": "fr",
#         "original_title": "My dad never told me I love you",
#         "overview": "Portrait of a father seen by his son.",
#         "popularity": 0.6,
#         "poster_path": "/xeYhVhE3wCBdvXaZcxJ68FIkjP8.jpg",
#         "release_date": "2024-02-02",
#         "title": "My dad never told me I love you",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/qDKmkuJhxJDLJFuUacWLdmya5TN.jpg",
#         "genre_ids": [
#             18,
#             10749
#         ],
#         "id": 487850,
#         "original_language": "ja",
#         "original_title": "\u5bdd\u3066\u3082\u899a\u3081\u3066\u3082",
#         "overview": "College student Asako falls in love at first sight with Baku after meeting at a photography exhibit. Romance sparks between the two but doesn't last long when Baku suddenly disappears from her life. Two years later, she spots a man that bears a striking resemblance to him. Even though it is only his physical similarities to Baku that attracted her to him, she doesn't say so and starts dating the soft-spoken young man called Ryohei.",
#         "popularity": 11.186,
#         "poster_path": "/aOxfXSpWrTSszS3vGVMqMHZ7SeC.jpg",
#         "release_date": "2018-09-01",
#         "title": "Asako I & II",
#         "video": false,
#         "vote_average": 6.8,
#         "vote_count": 159
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/DpPoSYKlfcHUdOLQNdaUiF7liS.jpg",
#         "genre_ids": [
#             10749,
#             18
#         ],
#         "id": 568467,
#         "original_language": "en",
#         "original_title": "Ammonite",
#         "overview": "In 1840s England, palaeontologist Mary Anning and a young woman sent by her husband to convalesce by the sea develop an intense relationship. Despite the chasm between their social spheres and personalities, Mary and Charlotte discover they can each offer what the other has been searching for: the realisation that they are not alone. It is the beginning of a passionate and all-consuming love affair that will defy all social bounds and alter the course of both lives irrevocably.",
#         "popularity": 26.617,
#         "poster_path": "/5lx4pUHWZoOKJWsVsvurRRNW9FK.jpg",
#         "release_date": "2020-11-13",
#         "title": "Ammonite",
#         "video": false,
#         "vote_average": 7.0,
#         "vote_count": 532
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [],
#         "id": 1116655,
#         "original_language": "en",
#         "original_title": "Ammonite",
#         "overview": "Upon discovering an SD card on a beach from 2009, an autistic trans woman looks through a decade of cringe photos in her camera roll to see who she\u2019s become.",
#         "popularity": 0.6,
#         "poster_path": null,
#         "release_date": "2021-10-17",
#         "title": "Ammonite",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/8HIIex1ySoFZ3Up7WJANrOllHMB.jpg",
#         "genre_ids": [],
#         "id": 392170,
#         "original_language": "ja",
#         "original_title": "\u30a2\u30f3\u30e2\u30ca\u30a4\u30c8\u306e\u3055\u3055\u3084\u304d\u3092\u805e\u3044\u305f",
#         "overview": "Ammonites were a kind of snail-like precursor to today's mollusks, common in the seas of the Cretaceous period, many millions of years ago. They are among the most commonly found fossils, so they must have been extremely plentiful. In this meditative and largely unstructured first feature, a young geologist is traveling by train to visit his sister in the countryside after having received a disturbing and mysterious letter from her. As he travels, he remembers his childhood fixation with rocks, nurtured by his mother, and his very strong affection for his sister.",
#         "popularity": 0.6,
#         "poster_path": "/nmCjcbq6fkf8SIjknZ3ZwndErzb.jpg",
#         "release_date": "1992-07-25",
#         "title": "I've Heard the Ammonite Murmur",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/30COvn7g7PP58wBkrnnh7Ws9bJS.jpg",
#         "genre_ids": [
#             10749,
#             35
#         ],
#         "id": 828613,
#         "original_language": "en",
#         "original_title": "About Fate",
#         "overview": "Two strangers believe in love but never seem to be able to find its true meaning. In a wild twist of events, fate puts each in the other's path on one stormy New Year's Eve.",
#         "popularity": 29.703,
#         "poster_path": "/fabZkaVHYJ67KbZx7oFoitauX34.jpg",
#         "release_date": "2022-09-08",
#         "title": "About Fate",
#         "video": false,
#         "vote_average": 7.5,
#         "vote_count": 345
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [],
#         "id": 919068,
#         "original_language": "de",
#         "original_title": "Rede nur niemand von Schicksal",
#         "overview": "",
#         "popularity": 0.6,
#         "poster_path": null,
#         "release_date": "1991-01-02",
#         "title": "Don't Talk About Fate",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/vP2kYhUZVMiZIZ9KSINp485A7oK.jpg",
#         "genre_ids": [
#             18
#         ],
#         "id": 41187,
#         "original_language": "tr",
#         "original_title": "Yazg\u0131",
#         "overview": "Musa, a customs clerk, lives quietly with his mother. Tragedy and change come for him, as they do for everyone, and he must confront his own attitude towards life\u2019s absurdity.",
#         "popularity": 2.468,
#         "poster_path": "/qGG8UlkKCS5l4qbYcx7hzfJ8yde.jpg",
#         "release_date": "2001-02-01",
#         "title": "Fate",
#         "video": false,
#         "vote_average": 7.4,
#         "vote_count": 48
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/ruxOWt2iCPM4tV2PY3OuYJHt4Do.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 624808,
#         "original_language": "en",
#         "original_title": "Love Wedding Repeat",
#         "overview": "While trying to make his sister's wedding day go smoothly, Jack finds himself juggling an angry ex-girlfriend, an uninvited guest with a secret, a misplaced sleep sedative, and the girl that got away in alternate versions of the same day.",
#         "popularity": 15.193,
#         "poster_path": "/u0MV99rB1hv8tkjtBJHfwIGCVKD.jpg",
#         "release_date": "2020-04-10",
#         "title": "Love Wedding Repeat",
#         "video": false,
#         "vote_average": 5.6,
#         "vote_count": 679
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/R2cpJHKCY0kQaaBV29tM8QVJ8B.jpg",
#         "genre_ids": [
#             10749,
#             18
#         ],
#         "id": 428493,
#         "original_language": "en",
#         "original_title": "God's Own Country",
#         "overview": "A young farmer in rural Yorkshire numbs his daily frustrations with binge drinking and casual sex, until the arrival of a Romanian migrant worker.",
#         "popularity": 17.357,
#         "poster_path": "/uKShYyGsleXAZ6e6gK5jF6Wa2tW.jpg",
#         "release_date": "2017-09-01",
#         "title": "God's Own Country",
#         "video": false,
#         "vote_average": 7.8,
#         "vote_count": 862
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/65BrpnfNIDTb0zAeAi7EVm4cf7W.jpg",
#         "genre_ids": [
#             53,
#             18
#         ],
#         "id": 269820,
#         "original_language": "ml",
#         "original_title": "\u0d17\u0d4b\u0d21\u0d4d\u0d38\u0d4d Own Country",
#         "overview": "Manu travels from Dubai to Kochi to attain his goal, without which he will be in trouble. Public prosecutor Mathew Tharakan and taxi driver Muhammed have their own intentions to be pursued as well. Vasudeva Sanal's God's Own Country narrates the story of what happens to the three as they try to reach their destination.",
#         "popularity": 2.358,
#         "poster_path": "/2uw4AZqUXVat8NdAhUJV1lGTRXO.jpg",
#         "release_date": "2014-05-09",
#         "title": "God's Own Country",
#         "video": false,
#         "vote_average": 5.4,
#         "vote_count": 7
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/pa0Mq5rGm2QnzdpFmugTu4Mghf.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 734265,
#         "original_language": "en",
#         "original_title": "Love Hard",
#         "overview": "An LA girl, unlucky in love, falls for an East Coast guy on a dating app and decides to surprise him for Christmas, only to discover that she's been catfished. But the object of her affection actually lives in the same town, and the guy who duped her offers to set them up if she pretends to be his own girlfriend for the holidays.",
#         "popularity": 14.617,
#         "poster_path": "/oTkAFDZRLnqrXOrOwuy3Tvul0v5.jpg",
#         "release_date": "2021-11-05",
#         "title": "Love Hard",
#         "video": false,
#         "vote_average": 6.956,
#         "vote_count": 1413
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/prNSFGKGjtc2lYEr8zjDastCeEg.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 552687,
#         "original_language": "ja",
#         "original_title": "\u30f2\u30bf\u30af\u306b\u604b\u306f\u96e3\u3057\u3044",
#         "overview": "An effervescent musical about one of the most unlikely couples seen on screen: two Otaku intent on hiding their nerdiness from their colleagues!",
#         "popularity": 13.381,
#         "poster_path": "/9JV0LOcazudqEcz2NNOMqEIzACz.jpg",
#         "release_date": "2020-02-07",
#         "title": "Wotakoi: Love is Hard for Otaku",
#         "video": false,
#         "vote_average": 6.7,
#         "vote_count": 52
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/ybVQnMIiPnBK21YTyDDW01LIhc9.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 252441,
#         "original_language": "ja",
#         "original_title": "\u30d4\u30f3\u30af\u30ab\u30c3\u30c8\u3000\u592a\u304f\u611b\u3057\u3066\u6df1\u304f\u611b\u3057\u3066",
#         "overview": "Mayumi and Mai are hair stylists who open a Barber shop called The Pink Cut. The place is an immediate success, due mostly to their super-short skirts. When the girls decide to stop wearing underpanties, business goes thru the roof. Eventually Main and Mayumi add special massages and cream rinses to their list of extras. The girls laugh all the way to the bank. Ah, the joys of entrepreneurship!",
#         "popularity": 3.291,
#         "poster_path": "/76lKLAY3PgZcs7gywNLhetLkz6L.jpg",
#         "release_date": "1983-01-21",
#         "title": "Pink Cut: Love Me Hard, Love Me Deep",
#         "video": false,
#         "vote_average": 3.5,
#         "vote_count": 6
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/m7nyXeceY0zsHEY9Klf0c2ZnoRV.jpg",
#         "genre_ids": [
#             99
#         ],
#         "id": 833999,
#         "original_language": "zh",
#         "original_title": "\u201c\u70bc\u201d\u7231",
#         "overview": "A documentary on five single women living in cities.",
#         "popularity": 0.6,
#         "poster_path": "/h0THMoAo7CBwSS7b7mhEIsI7Pk4.jpg",
#         "release_date": "2021-06-12",
#         "title": "Hard Love",
#         "video": false,
#         "vote_average": 6.5,
#         "vote_count": 2
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/ejKTeZpMenQDjr2FlbX9s1kYDdu.jpg",
#         "genre_ids": [
#             10749,
#             18,
#             80
#         ],
#         "id": 39125,
#         "original_language": "en",
#         "original_title": "Love the Hard Way",
#         "overview": "Claire, a brilliant student, seeks answers to the meaning of life in the calm of her biology laboratory. One day, she meets a mysterious young man, Jack, at the cinema, and is intrigued by his style, assurance and audacity. Apart from his artistic activities, Jack has a regular scam going, ripping off foreign businessmen with his loyal mate Charlie and two actresses. But his tough guy exterior conceals a secret passion for old books, and he dreams of writing a novel one day. Jack falls hard for Claire's purity and curiosity. An unusual romance develops between them. But Jack is scared of their growing intimacy and rejects Claire, withdrawing into his shell. Abandoned and confused, Claire gradually begins to neglect her studies and embarks on a spiraling course of self-destruction, whilst Jack, who tries to ignore her, concentrates on his criminal activities. However, a sharp detective, named Linda Fox, is following his dodgy tracks.",
#         "popularity": 3.888,
#         "poster_path": "/f3QvdfN1tE3Rf3oUhezBQBbgX4i.jpg",
#         "release_date": "2003-03-27",
#         "title": "Love the Hard Way",
#         "video": false,
#         "vote_average": 6.3,
#         "vote_count": 24
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             35
#         ],
#         "id": 419343,
#         "original_language": "fr",
#         "original_title": "Hard Love",
#         "overview": "Sex comedy.",
#         "popularity": 1.774,
#         "poster_path": null,
#         "release_date": "1975-11-26",
#         "title": "Hard Love",
#         "video": false,
#         "vote_average": 1.0,
#         "vote_count": 1
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             35
#         ],
#         "id": 1045374,
#         "original_language": "en",
#         "original_title": "Hard Love",
#         "overview": "A break-up between a couple leads them to having a garage sale, only to find out that the two have more skeletons in the closet than they do junk.",
#         "popularity": 1.602,
#         "poster_path": null,
#         "release_date": "2011-10-15",
#         "title": "Hard Love",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/u83bKahLAsAhYCbcP4C1XzEDt4p.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 43846,
#         "original_language": "en",
#         "original_title": "Love Finds Andy Hardy",
#         "overview": "Andy Hardy becomes entangled with three different girls all at the same time.",
#         "popularity": 4.976,
#         "poster_path": "/eemy6iN41zgrKFmPUZo49SaJVbo.jpg",
#         "release_date": "1938-07-22",
#         "title": "Love Finds Andy Hardy",
#         "video": false,
#         "vote_average": 6.1,
#         "vote_count": 22
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/8WiwDBrpGDMiHRoeP904WGtfqU8.jpg",
#         "genre_ids": [
#             35,
#             10749
#         ],
#         "id": 43483,
#         "original_language": "en",
#         "original_title": "Love Laughs at Andy Hardy",
#         "overview": "Andy Hardy goes to college after serving in the war and finds his sweetheart is engaged to someone else.",
#         "popularity": 2.663,
#         "poster_path": "/v9KOUCgJRgWEQbhHcZJaoGrwyGH.jpg",
#         "release_date": "1946-12-25",
#         "title": "Love Laughs at Andy Hardy",
#         "video": false,
#         "vote_average": 5.3,
#         "vote_count": 10
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             18,
#             10749
#         ],
#         "id": 419370,
#         "original_language": "en",
#         "original_title": "Boys On Film 1: Hard Love",
#         "overview": "Created by gay directors and actors, Boys On Film features numerous award-winning shorts that deal with all aspects of gay life. Volume 1: Hard Love contains nine complete films: Hong Khaou's \"Summer\" starring Peter Peralta and Jay Brown; Michael Simon's \"Gay Zombie\" starring Brad Bilanin, Ryan Carlberg, and Robin McDonald;  Jason Bushman's \"Serene Hunter\" starring Eric Debets, Flannan Ob\u00e9, and Jonathan Blanc; Timothy Smith's \"Le Weekend\" starring Omar and Fernando Peres; Jean Baptiste Erreca's \"Cowboy Forever\" featuring Govinda Machado de Figueiredo and Jones Carlos Fialho de Ara\u00fajo; Damien Rea's \"Scarred\" starring Chris Anderson, David Durham, and Lara Cazalet; Tim Hunter's \"Packed Lunch\" featuring Kevyn Boemia, Chris Sayers, and Steven Quigg; John Winter's \"Mirror Mirror\" starring Roy Billing; and Maxwell Barber's \"VGL-Hung!\" starring Marcus Proctor, Jeff Chandler, and Ashley Ryder.",
#         "popularity": 1.4,
#         "poster_path": "/hx1nG4zfyVrVJ0NCGlf9lfJc7Au.jpg",
#         "release_date": "2009-03-09",
#         "title": "Boys On Film 1: Hard Love",
#         "video": true,
#         "vote_average": 5.3,
#         "vote_count": 5
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             10770,
#             53
#         ],
#         "id": 252306,
#         "original_language": "en",
#         "original_title": "Sex, Love and Cold Hard Cash",
#         "overview": "An ex-con whose share of a robbery disappeared joins forces with deluxe edition call-girl in order to get back the money she gave her accountant for investment purposes. The chase will lead them to the Carrabeans where they will have to go on a cruise...",
#         "popularity": 0.6,
#         "poster_path": null,
#         "release_date": "1993-05-13",
#         "title": "Sex, Love and Cold Hard Cash",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             35
#         ],
#         "id": 1155217,
#         "original_language": "en",
#         "original_title": "Hard Knocks and Love Taps",
#         "overview": "When a well off man from the city arrives in a hick town to woo a wealthy widow, he encounters first an ornery model T ride to the shabby hotel, then his rival for the widow as they go on to a local fair. tempers flair and a challenge to a boxing match is met.",
#         "popularity": 0.652,
#         "poster_path": "/mHKPIvIG4DQr9rDRwaFwzkvLXBL.jpg",
#         "release_date": "1921-07-24",
#         "title": "Hard Knocks and Love Taps",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/pAo9WP8twr3cHVH7oS5ywEuub8C.jpg",
#         "genre_ids": [
#             99
#         ],
#         "id": 8893,
#         "original_language": "fr",
#         "original_title": "C'est dur d'\u00eatre aim\u00e9 par des cons",
#         "overview": "The murder of Dutch filmmaker Theo van Gogh by an Islamic extremist in 2004, followed by the publishing of twelve satirical cartoons depicting the prophet Mohammed that was commissioned for the Danish newspaper Jyllands-Posten, provides the incendiary framework for Daniel Leconte's provocative documentary, It's Hard Being Loved by Jerks.",
#         "popularity": 2.293,
#         "poster_path": "/nOoKOLYaZmTBQ5heT3xg9dn0lOO.jpg",
#         "release_date": "2008-09-17",
#         "title": "It's Hard Being Loved by Jerks",
#         "video": false,
#         "vote_average": 6.8,
#         "vote_count": 8
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             99
#         ],
#         "id": 287058,
#         "original_language": "de",
#         "original_title": "Roadcrew \u2013 Live Fast, Love Hard & Die Young!",
#         "overview": "",
#         "popularity": 0.6,
#         "poster_path": null,
#         "release_date": "2011-10-27",
#         "title": "Roadcrew \u2013 Live Fast, Love Hard & Die Young!",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             99
#         ],
#         "id": 48692,
#         "original_language": "en",
#         "original_title": "Marie and Jack: A Hardcore Love Story",
#         "overview": "Marie Silva and Jack Bravo are a married couple who also happen to make porn films for a living. This documentary examines what a marriage involving a couple whose jobs it is to have sex with other people is like, what the pressures are and the differences between their professional lives and their personal lives.",
#         "popularity": 0.6,
#         "poster_path": "/nmY7pF6LEboR7Ht23yYxP98Q6Eg.jpg",
#         "release_date": "2002-01-01",
#         "title": "Marie and Jack: A Hardcore Love Story",
#         "video": false,
#         "vote_average": 7.0,
#         "vote_count": 3
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [
#             10751,
#             35
#         ],
#         "id": 252586,
#         "original_language": "en",
#         "original_title": "The All New Adventures of Laurel & Hardy in For Love or Mummy",
#         "overview": "Bronson Pinchot does a nice job imitating Stan Laurel and Gailard Sartain gives a good appearance as Oliver Hardy, but the imitation does not extend to the original duo's comedy. The silly story line finds the two trying to protect a professor's daughter from a mummy that has been re-born",
#         "popularity": 0.855,
#         "poster_path": "/i8BnDRl4YMmx6q9uTvfc2hsCbtz.jpg",
#         "release_date": "1999-01-27",
#         "title": "The All New Adventures of Laurel & Hardy in For Love or Mummy",
#         "video": false,
#         "vote_average": 4.2,
#         "vote_count": 5
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/lFJn0PN0LEbbuqdBtfXcvZdABo2.jpg",
#         "genre_ids": [
#             18,
#             10770
#         ],
#         "id": 86040,
#         "original_language": "en",
#         "original_title": "To Sir, with Love II",
#         "overview": "After thirty years teaching in London, Mark Thackeray retires and returns to Chicago. There, however, the challenge of teaching kids in an inner city school proves to be too much to resist.",
#         "popularity": 9.807,
#         "poster_path": "/94gHDqRoScMy6JIydYWsE3QBwea.jpg",
#         "release_date": "1996-04-07",
#         "title": "To Sir, With Love II",
#         "video": false,
#         "vote_average": 6.4,
#         "vote_count": 53
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/FtqNULVyTU2EaIPl252rk7o3oD.jpg",
#         "genre_ids": [
#             99
#         ],
#         "id": 441188,
#         "original_language": "es",
#         "original_title": "Chavela",
#         "overview": "Inspired by an exclusive interview and performance footage of Chavela Vargas shot in 1991 and guided by her unique voice, the film weaves an arresting portrait of a woman who dared to dress, speak, sing, and dream her unique life into being.",
#         "popularity": 4.425,
#         "poster_path": "/owutg7PpHuy82Gu9C0awXqcsEJ2.jpg",
#         "release_date": "2017-06-16",
#         "title": "Chavela",
#         "video": false,
#         "vote_average": 7.0,
#         "vote_count": 22
#     },
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "genre_ids": [],
#         "id": 1026127,
#         "original_language": "ja",
#         "original_title": "\u3082\u3063\u3068\u6fc0\u3057\u304f\u3082\u3063\u3068\u3064\u3088\u304f",
#         "overview": "",
#         "popularity": 0.906,
#         "poster_path": "/q99vT621t7yckcofPfsfm89K8BL.jpg",
#         "release_date": "1981-05-15",
#         "title": "Motto hageshiku motto tsuyoku",
#         "video": false,
#         "vote_average": 2.0,
#         "vote_count": 1
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/uZI8MxQxLSJXOgcdwGrLPCfdK2y.jpg",
#         "genre_ids": [
#             10402,
#             99
#         ],
#         "id": 765057,
#         "original_language": "en",
#         "original_title": "69: The Saga of Danny Hernandez",
#         "overview": "Part investigative documentary, part real-life gangster movie, this film unpacks the life of polarizing rap sensation and internet troll Tekashi69, aka 69, while chronicling his meteoric rise and fall from fame.",
#         "popularity": 2.209,
#         "poster_path": "/5xXGQLVtTAExHY92DHD9ewGmKxf.jpg",
#         "release_date": "2021-04-29",
#         "title": "69: The Saga of Danny Hernandez",
#         "video": false,
#         "vote_average": 6.0,
#         "vote_count": 12
#     },
#     {
#         "adult": false,
#         "backdrop_path": "/DOvdZIFEVXCGQrLtV5NU57OKUQ.jpg",
#         "genre_ids": [
#             99,
#             10402,
#             36
#         ],
#         "id": 502190,
#         "original_language": "en",
#         "original_title": "A Tuba To Cuba",
#         "overview": "A son seeking to fulfill his late father\u2019s dream takes his band from the storied city of New Orleans to the shores of Cuba, where \u2014 through the universal language of music \u2014 dark and ancient connections between their peoples reveal the roots of jazz.",
#         "popularity": 2.244,
#         "poster_path": "/wJ67X3LbjbPHGEoSh6bh2CRabze.jpg",
#         "release_date": "2019-02-15",
#         "title": "A Tuba To Cuba",
#         "video": false,
#         "vote_average": 6.6,
#         "vote_count": 8
#     }
# ]

# %%
# convert details_results_list to Dataframe
nyt_details_df = pd.DataFrame(details_results_list)
nyt_df.head(5)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2018/01/18/movies/kang...
# 1  https://www.nytimes.com/2018/11/01/movies/they...
# 2  https://www.nytimes.com/2016/06/24/movies/from...
# 3  https://www.nytimes.com/2021/10/14/movies/hard...
# 4  https://www.nytimes.com/2019/08/29/movies/fall...
#
#                                              snippet              source  \
# 0  The documentary looks at the mass killings of ...  The New York Times
# 1  Morgan Neville’s movie tells the tumultuous be...  The New York Times
# 2  Sharon Shattuck’s documentary tells her family...  The New York Times
# 3  Drawn from the plotline of a Todd Snider song,...  The New York Times
# 4  It’s hard to find a reliable, talented, reason...  The New York Times
#
#                                             keywords  \
# 0  creative_works: Kangaroo: A Love-Hate Story (M...
# 1  subject: Documentary Films and Programs;creati...
# 2  subject: Documentary Films and Programs;person...
# 3  subject: Movies;persons: Dorman, Michael (1981...
# 4  subject: Movies;organizations: Netflix Inc;per...
#
#                    pub_date  word_count  \
# 0  2018-01-18T12:00:23+0000         263
# 1  2018-11-01T13:56:39+0000         794
# 2  2016-06-23T21:11:31+0000         252
# 3  2021-10-14T12:27:03+0000         320
# 4  2019-08-29T14:56:44+0000         374
#
#                                        headline.main         headline.kicker  \
# 0  Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...                    None
# 1  Review: ‘They’ll Love Me When I’m Dead’ Docume...                    None
# 2  Review: ‘From This Day Forward’ Attests to Lov...                    None
# 3  ‘Hard Luck Love Song’ Review: A Glossy Take on...                    None
# 4  ‘Falling Inn Love’ Review: A Prize That Needs ...  Streaming Movie Review
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None                        Kangaroo: A Love-Hate Story
# 1                    None                       The Legend Behind The Scenes
# 2                    None  Review: ‘From This Day Forward’ Attests to Lov...
# 3                    None                                Hard Luck Love Song
# 4                    None        A Fine Romance to Watch While Sorting Socks
#
#   headline.name headline.seo headline.sub       byline.original  \
# 0          None         None         None     By Ken Jaworowski
# 1          None         None         None     By Manohla Dargis
# 2          None         None         None       By Andy Webster
# 3          None         None         None        By Glenn Kenny
# 4          None         None         None  By Helen T. Verongos
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 1  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 2  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Helen', 'middlename': 'T.', 'l...                None
#
#                                                title
# 0  Kangaroo: A Love-Hate Story’ Exposes a Wildlif...
# 1  They’ll Love Me When I’m Dead’ Documents Orson...
# 2  From This Day Forward’ Attests to Love’s Adapt...
# 3                                Hard Luck Love Song
# 4                                   Falling Inn Love

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df.head(5)
# Out:
#    adult                     backdrop_path               genre_ids      id  \
# 0  False  /l17qkQS5Goz1asb2Zs5LsopGIK3.jpg  [10749, 10402, 18, 53]  536208
# 1  False  /lVJdFZc8hBJRVnOIay60tl04Qjv.jpg             [10749, 35]  623195
# 2  False  /dn7wTIud3Yroopm8bWN8WtidTBW.jpg                [35, 36]  544510
# 3  False  /uRJb4Ukin4pQeTuyv07TqsBQt72.jpg                 [10749]  445179
# 4  False  /27ZkYMWynuK2qiDP6awc3MsCaOs.jpg             [10749, 18]  527641
#
#   original_language          original_title  \
# 0                en     Hard Luck Love Song
# 1                en        Falling Inn Love
# 2                fr                  Edmond
# 3                ja  わたしに運命の恋なんてありえないって思ってた
# 4                en         Five Feet Apart
#
#                                             overview  popularity  \
# 0  Jesse, a charismatic but down on his luck trou...       3.851
# 1  When a San Francisco exec wins a New Zealand i...      17.920
# 2  Paris, France, December 1897. The young playwr...      11.720
# 3  Riko is 27, working as a love simulation game ...       7.340
# 4  Seventeen-year-old Stella spends most of her t...      56.515
#
#                         poster_path release_date                       title  \
# 0  /fWUbYGT0zTJoEZVyc2SvsenoHPF.jpg   2021-10-15         Hard Luck Love Song
# 1  /4bzu5k5vwLKgwap6pHXlCY8nlh3.jpg   2019-08-29            Falling Inn Love
# 2  /9Y1VxSfJdu8fqQqgX0x6OObxvUw.jpg   2018-11-10             Cyrano, My Love
# 3  /nBrixx0zRnOufOaK9oVBUGlTS5f.jpg   2017-12-23  My Long Awaited Love Story
# 4  /kreTuJBkUjVWePRfhHZuYfhNE1T.jpg   2019-03-14             Five Feet Apart
#
#    video  vote_average  vote_count
# 0  False         4.900          10
# 1  False         6.500        1114
# 2  False         7.500         476
# 3  False         8.100           5
# 4  False         8.271        5395

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title

combined_df = pd.merge(nyt_df, tmdb_df, how='inner', on='title')
combined_df2 = pd.merge(combined_df, nyt_details_df, how='inner', on='title')

# Set index to "Country of Nationality"
combined_df2 = combined_df2.set_index("title")
combined_df2
# Out:
#                                                                            web_url  \
# title
# Hard Luck Love Song              https://www.nytimes.com/2021/10/14/movies/hard...
# Falling Inn Love                 https://www.nytimes.com/2019/08/29/movies/fall...
# Cyrano, My Love                  https://www.nytimes.com/2019/10/17/movies/cyra...
# Five Feet Apart                  https://www.nytimes.com/2019/03/14/movies/five...
# I Love My Dad                    https://www.nytimes.com/2022/08/04/movies/i-lo...
# Asako I & II                     https://www.nytimes.com/2019/05/16/movies/asak...
# Ammonite                         https://www.nytimes.com/2020/11/12/movies/ammo...
# Ammonite                         https://www.nytimes.com/2020/11/12/movies/ammo...
# Ammonite                         https://www.nytimes.com/2020/11/12/movies/ammo...
# Ammonite                         https://www.nytimes.com/2020/11/12/movies/ammo...
# About Fate                       https://www.nytimes.com/2022/09/08/movies/abou...
# Love Wedding Repeat              https://www.nytimes.com/2020/04/10/movies/love...
# Love Hard                        https://www.nytimes.com/2021/11/05/movies/love...
# 69: The Saga of Danny Hernandez  https://www.nytimes.com/2020/11/17/movies/69-s...
#
#                                                                            snippet  \
# title
# Hard Luck Love Song              Drawn from the plotline of a Todd Snider song,...
# Falling Inn Love                 It’s hard to find a reliable, talented, reason...
# Cyrano, My Love                  This superficial take on the writing and initi...
# Five Feet Apart                  Haley Lu Richardson and Cole Sprouse navigate ...
# I Love My Dad                    This comedy is a daddy-issues movie with a que...
# Asako I & II                     The Japanese director Ryusuke Hamaguchi follow...
# Ammonite                         Kate Winslet’s fossil hunter and Saoirse Ronan...
# Ammonite                         Kate Winslet’s fossil hunter and Saoirse Ronan...
# Ammonite                         Kate Winslet’s fossil hunter and Saoirse Ronan...
# Ammonite                         Kate Winslet’s fossil hunter and Saoirse Ronan...
# About Fate                       Thomas Mann’s beguiling performance drives thi...
# Love Wedding Repeat              A couple’s reception becomes a disaster (or do...
# Love Hard                        When a perennially single journalist travels a...
# 69: The Saga of Danny Hernandez  The rise and fall of the provocative rapper Te...
#
#                                              source  \
# title
# Hard Luck Love Song              The New York Times
# Falling Inn Love                 The New York Times
# Cyrano, My Love                  The New York Times
# Five Feet Apart                  The New York Times
# I Love My Dad                    The New York Times
# Asako I & II                     The New York Times
# Ammonite                         The New York Times
# Ammonite                         The New York Times
# Ammonite                         The New York Times
# Ammonite                         The New York Times
# About Fate                       The New York Times
# Love Wedding Repeat              The New York Times
# Love Hard                        The New York Times
# 69: The Saga of Danny Hernandez  The New York Times
#
#                                                                           keywords  \
# title
# Hard Luck Love Song              subject: Movies;persons: Dorman, Michael (1981...
# Falling Inn Love                 subject: Movies;organizations: Netflix Inc;per...
# Cyrano, My Love                  subject: Movies;creative_works: Cyrano, My Lov...
# Five Feet Apart                  subject: Movies;creative_works: Five Feet Apar...
# I Love My Dad                    subject: Movies;persons: Oswalt, Patton;creati...
# Asako I & II                     subject: Movies;creative_works: Asako I & II (...
# Ammonite                         subject: Movies;persons: Ronan, Saoirse;person...
# Ammonite                         subject: Movies;persons: Ronan, Saoirse;person...
# Ammonite                         subject: Movies;persons: Ronan, Saoirse;person...
# Ammonite                         subject: Movies;persons: Ronan, Saoirse;person...
# About Fate                       subject: Movies;creative_works: About Fate (Mo...
# Love Wedding Repeat              subject: Movies;creative_works: Love Wedding R...
# Love Hard                        subject: Movies;creative_works: Love Hard (Mov...
# 69: The Saga of Danny Hernandez  subject: Documentary Films and Programs;subjec...
#
#                                                  pub_date  word_count  \
# title
# Hard Luck Love Song              2021-10-14T12:27:03+0000         320
# Falling Inn Love                 2019-08-29T14:56:44+0000         374
# Cyrano, My Love                  2019-10-17T11:00:03+0000         291
# Five Feet Apart                  2019-03-14T13:00:07+0000         258
# I Love My Dad                    2022-08-04T11:00:05+0000         418
# Asako I & II                     2019-05-16T11:00:01+0000         547
# Ammonite                         2020-11-12T12:00:04+0000         510
# Ammonite                         2020-11-12T12:00:04+0000         510
# Ammonite                         2020-11-12T12:00:04+0000         510
# Ammonite                         2020-11-12T12:00:04+0000         510
# About Fate                       2022-09-09T01:00:03+0000         289
# Love Wedding Repeat              2020-04-10T07:01:05+0000         414
# Love Hard                        2021-11-05T07:01:03+0000         343
# 69: The Saga of Danny Hernandez  2020-11-17T19:07:20+0000         363
#
#                                                                      headline.main  \
# title
# Hard Luck Love Song              ‘Hard Luck Love Song’ Review: A Glossy Take on...
# Falling Inn Love                 ‘Falling Inn Love’ Review: A Prize That Needs ...
# Cyrano, My Love                       ‘Cyrano, My Love’ Review: A Nose for Romance
# Five Feet Apart                  ‘Five Feet Apart’ Review: Ailing Teenagers Liv...
# I Love My Dad                    ‘I Love My Dad’ Review: A Father Catfishes His...
# Asako I & II                     ‘Asako I & II’ Review: Double the Love (and th...
# Ammonite                                      ‘Ammonite’ Review: Love on the Rocks
# Ammonite                                      ‘Ammonite’ Review: Love on the Rocks
# Ammonite                                      ‘Ammonite’ Review: Love on the Rocks
# Ammonite                                      ‘Ammonite’ Review: Love on the Rocks
# About Fate                          ‘About Fate’ Review: Love the One You’re With?
# Love Wedding Repeat              ‘Love Wedding Repeat’ Review: A Tumble Down th...
# Love Hard                        ‘Love Hard’ Review: Seeking Connection, Not Pe...
# 69: The Saga of Danny Hernandez  ‘69: The Saga of Danny Hernandez’ Review: A So...
#
#                                         headline.kicker  \
# title
# Hard Luck Love Song                                None
# Falling Inn Love                 Streaming Movie Review
# Cyrano, My Love                                    None
# Five Feet Apart                                    None
# I Love My Dad                                      None
# Asako I & II                              Critic’s Pick
# Ammonite                                  Critic’s Pick
# Ammonite                                  Critic’s Pick
# Ammonite                                  Critic’s Pick
# Ammonite                                  Critic’s Pick
# About Fate                                         None
# Love Wedding Repeat                        Movie Review
# Love Hard                                          None
# 69: The Saga of Danny Hernandez                    None
#
#                                 headline.content_kicker  \
# title
# Hard Luck Love Song                                None
# Falling Inn Love                                   None
# Cyrano, My Love                                    None
# Five Feet Apart                                    None
# I Love My Dad                                      None
# Asako I & II                                       None
# Ammonite                                           None
# Ammonite                                           None
# Ammonite                                           None
# Ammonite                                           None
# About Fate                                         None
# Love Wedding Repeat                                None
# Love Hard                                          None
# 69: The Saga of Danny Hernandez                    None
#
#                                                            headline.print_headline  \
# title
# Hard Luck Love Song                                            Hard Luck Love Song
# Falling Inn Love                       A Fine Romance to Watch While Sorting Socks
# Cyrano, My Love                                                    Cyrano, My Love
# Five Feet Apart                                                    Five Feet Apart
# I Love My Dad                    A Father Catfishes His Son. We Just Wait for t...
# Asako I & II                               Falling For a Drifter And His Lookalike
# Ammonite                                                         Love on the Rocks
# Ammonite                                                         Love on the Rocks
# Ammonite                                                         Love on the Rocks
# Ammonite                                                         Love on the Rocks
# About Fate                                                              About Fate
# Love Wedding Repeat                                     Pratfalling Down The Aisle
# Love Hard                                                                Love Hard
# 69: The Saga of Danny Hernandez           Loved in Hip-Hop, but Loathed in the End
#
#                                  ...  \
# title                            ...
# Hard Luck Love Song              ...
# Falling Inn Love                 ...
# Cyrano, My Love                  ...
# Five Feet Apart                  ...
# I Love My Dad                    ...
# Asako I & II                     ...
# Ammonite                         ...
# Ammonite                         ...
# Ammonite                         ...
# Ammonite                         ...
# About Fate                       ...
# Love Wedding Repeat              ...
# Love Hard                        ...
# 69: The Saga of Danny Hernandez  ...
#
#                                                                   details_overview  \
# title
# Hard Luck Love Song              Jesse, a charismatic but down on his luck trou...
# Falling Inn Love                 When a San Francisco exec wins a New Zealand i...
# Cyrano, My Love                  Paris, France, December 1897. The young playwr...
# Five Feet Apart                  Seventeen-year-old Stella spends most of her t...
# I Love My Dad                    A hopelessly estranged father catfishes his so...
# Asako I & II                     College student Asako falls in love at first s...
# Ammonite                         Upon discovering an SD card on a beach from 20...
# Ammonite                         In 1840s England, palaeontologist Mary Anning ...
# Ammonite                         Upon discovering an SD card on a beach from 20...
# Ammonite                         In 1840s England, palaeontologist Mary Anning ...
# About Fate                       Two strangers believe in love but never seem t...
# Love Wedding Repeat              While trying to make his sister's wedding day ...
# Love Hard                        An LA girl, unlucky in love, falls for an East...
# 69: The Saga of Danny Hernandez  Part investigative documentary, part real-life...
#
#                                 details_popularity details_runtime  \
# title
# Hard Luck Love Song                          3.851             104
# Falling Inn Love                            17.920              98
# Cyrano, My Love                             11.720             113
# Five Feet Apart                             56.515             116
# I Love My Dad                                8.400              90
# Asako I & II                                11.186             119
# Ammonite                                     0.600               7
# Ammonite                                    26.617             118
# Ammonite                                     0.600               7
# Ammonite                                    26.617             118
# About Fate                                  29.703             100
# Love Wedding Repeat                         15.193             100
# Love Hard                                   14.617             105
# 69: The Saga of Danny Hernandez              2.209             101
#
#                                 details_revenue details_release_date  \
# title
# Hard Luck Love Song                           0           2021-10-15
# Falling Inn Love                              0           2019-08-29
# Cyrano, My Love                               0           2018-11-10
# Five Feet Apart                        92600000           2019-03-14
# I Love My Dad                                 0           2022-08-05
# Asako I & II                                  0           2018-09-01
# Ammonite                                      0           2021-10-17
# Ammonite                                1396905           2020-11-13
# Ammonite                                      0           2021-10-17
# Ammonite                                1396905           2020-11-13
# About Fate                                    0           2022-09-08
# Love Wedding Repeat                           0           2020-04-10
# Love Hard                                     0           2021-11-05
# 69: The Saga of Danny Hernandez               0           2021-04-29
#
#                                 details_vote_average  details_vote_count  \
# title
# Hard Luck Love Song                            4.900                  10
# Falling Inn Love                               6.500                1114
# Cyrano, My Love                                7.500                 476
# Five Feet Apart                                8.271                5395
# I Love My Dad                                  5.800                  42
# Asako I & II                                   6.800                 159
# Ammonite                                       0.000                   0
# Ammonite                                       7.000                 532
# Ammonite                                       0.000                   0
# Ammonite                                       7.000                 532
# About Fate                                     7.500                 345
# Love Wedding Repeat                            5.600                 679
# Love Hard                                      6.956                1413
# 69: The Saga of Danny Hernandez                6.000                  12
#
#                                                                      details_genre  \
# title
# Hard Luck Love Song              [{'id': 10749, 'name': 'Romance'}, {'id': 1040...
# Falling Inn Love                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# Cyrano, My Love                  [{'id': 35, 'name': 'Comedy'}, {'id': 36, 'nam...
# Five Feet Apart                  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# I Love My Dad                                       [{'id': 35, 'name': 'Comedy'}]
# Asako I & II                     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# Ammonite                                                                        []
# Ammonite                         [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# Ammonite                                                                        []
# Ammonite                         [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# About Fate                       [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# Love Wedding Repeat              [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# Love Hard                        [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 69: The Saga of Danny Hernandez  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
#
#                                                           details_spoken_languages  \
# title
# Hard Luck Love Song              [{'english_name': 'English', 'iso_639_1': 'en'...
# Falling Inn Love                 [{'english_name': 'English', 'iso_639_1': 'en'...
# Cyrano, My Love                  [{'english_name': 'French', 'iso_639_1': 'fr',...
# Five Feet Apart                  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# I Love My Dad                    [{'english_name': 'English', 'iso_639_1': 'en'...
# Asako I & II                     [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# Ammonite                                                                        []
# Ammonite                         [{'english_name': 'English', 'iso_639_1': 'en'...
# Ammonite                                                                        []
# Ammonite                         [{'english_name': 'English', 'iso_639_1': 'en'...
# About Fate                       [{'english_name': 'English', 'iso_639_1': 'en'...
# Love Wedding Repeat              [{'english_name': 'English', 'iso_639_1': 'en'...
# Love Hard                        [{'english_name': 'English', 'iso_639_1': 'en'...
# 69: The Saga of Danny Hernandez  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                       details_production_countries
# title
# Hard Luck Love Song              [{'iso_3166_1': 'US', 'name': 'United States o...
# Falling Inn Love                 [{'iso_3166_1': 'US', 'name': 'United States o...
# Cyrano, My Love                  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...
# Five Feet Apart                  [{'iso_3166_1': 'US', 'name': 'United States o...
# I Love My Dad                    [{'iso_3166_1': 'US', 'name': 'United States o...
# Asako I & II                               [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# Ammonite                                                                        []
# Ammonite                          [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Ammonite                                                                        []
# Ammonite                          [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# About Fate                       [{'iso_3166_1': 'US', 'name': 'United States o...
# Love Wedding Repeat              [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# Love Hard                        [{'iso_3166_1': 'US', 'name': 'United States o...
# 69: The Saga of Danny Hernandez  [{'iso_3166_1': 'US', 'name': 'United States o...
#
# [14 rows x 43 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
#print(combined_df2.dtypes)
combined_fixed_df = combined_df2.copy()
#The genres, spoken_languages, and production_countries columns were saved as lists, but we want the columns to be strings without the list characters ([, ], and '). To fix these columns, perform the following actions:
#Create a list of the columns that need fixing called columns_to_fix.
columns_to_fix = ['details_genre', 'details_spoken_languages', 'details_production_countries']
#Create a list of characters to remove called characters_to_remove.
characters_to_remove = ["[", "]", "'"]
#Loop through columns_to_fix and do the following:
#for fix_column in columns_to_fix:
def row_to_string(row,fix_column):  
    result_string = ''
    for dictionary in row[fix_column]:
        for key, value in dictionary.items():
            result_string += f" {value} "
            result_string = result_string.rstrip(', ').replace(characters_to_remove[0],'').replace('characters_to_remove[1]','').replace("characters_to_remove[3]",'')
    return result_string

combined_fixed_df['details_genre_fixed'] = combined_fixed_df.apply(lambda row: row_to_string(row,columns_to_fix[0] ), axis=1)
combined_fixed_df['details_spoken_languages_fixed'] = combined_fixed_df.apply(lambda row: row_to_string(row,columns_to_fix[1]), axis=1)
combined_fixed_df['details_production_countries_fixed'] = combined_fixed_df.apply(lambda row: row_to_string(row,columns_to_fix[2]), axis=1)
#print(combined_fixed_df['details_genre_fixed'])

#Use astype() to convert the column to a string.
#Loop through the characters_to_remove and use the Pandas str.replace() method to remove the character from the string.
#Print the head of the updated DataFrame to confirm the list characters were removed.
combined_fixed_df.head(5)
# Out:
#                                                                web_url  \
# title
# Hard Luck Love Song  https://www.nytimes.com/2021/10/14/movies/hard...
# Falling Inn Love     https://www.nytimes.com/2019/08/29/movies/fall...
# Cyrano, My Love      https://www.nytimes.com/2019/10/17/movies/cyra...
# Five Feet Apart      https://www.nytimes.com/2019/03/14/movies/five...
# I Love My Dad        https://www.nytimes.com/2022/08/04/movies/i-lo...
#
#                                                                snippet  \
# title
# Hard Luck Love Song  Drawn from the plotline of a Todd Snider song,...
# Falling Inn Love     It’s hard to find a reliable, talented, reason...
# Cyrano, My Love      This superficial take on the writing and initi...
# Five Feet Apart      Haley Lu Richardson and Cole Sprouse navigate ...
# I Love My Dad        This comedy is a daddy-issues movie with a que...
#
#                                  source  \
# title
# Hard Luck Love Song  The New York Times
# Falling Inn Love     The New York Times
# Cyrano, My Love      The New York Times
# Five Feet Apart      The New York Times
# I Love My Dad        The New York Times
#
#                                                               keywords  \
# title
# Hard Luck Love Song  subject: Movies;persons: Dorman, Michael (1981...
# Falling Inn Love     subject: Movies;organizations: Netflix Inc;per...
# Cyrano, My Love      subject: Movies;creative_works: Cyrano, My Lov...
# Five Feet Apart      subject: Movies;creative_works: Five Feet Apar...
# I Love My Dad        subject: Movies;persons: Oswalt, Patton;creati...
#
#                                      pub_date  word_count  \
# title
# Hard Luck Love Song  2021-10-14T12:27:03+0000         320
# Falling Inn Love     2019-08-29T14:56:44+0000         374
# Cyrano, My Love      2019-10-17T11:00:03+0000         291
# Five Feet Apart      2019-03-14T13:00:07+0000         258
# I Love My Dad        2022-08-04T11:00:05+0000         418
#
#                                                          headline.main  \
# title
# Hard Luck Love Song  ‘Hard Luck Love Song’ Review: A Glossy Take on...
# Falling Inn Love     ‘Falling Inn Love’ Review: A Prize That Needs ...
# Cyrano, My Love           ‘Cyrano, My Love’ Review: A Nose for Romance
# Five Feet Apart      ‘Five Feet Apart’ Review: Ailing Teenagers Liv...
# I Love My Dad        ‘I Love My Dad’ Review: A Father Catfishes His...
#
#                             headline.kicker headline.content_kicker  \
# title
# Hard Luck Love Song                    None                    None
# Falling Inn Love     Streaming Movie Review                    None
# Cyrano, My Love                        None                    None
# Five Feet Apart                        None                    None
# I Love My Dad                          None                    None
#
#                                                headline.print_headline  ...  \
# title                                                                   ...
# Hard Luck Love Song                                Hard Luck Love Song  ...
# Falling Inn Love           A Fine Romance to Watch While Sorting Socks  ...
# Cyrano, My Love                                        Cyrano, My Love  ...
# Five Feet Apart                                        Five Feet Apart  ...
# I Love My Dad        A Father Catfishes His Son. We Just Wait for t...  ...
#
#                     details_revenue details_release_date details_vote_average  \
# title
# Hard Luck Love Song               0           2021-10-15                4.900
# Falling Inn Love                  0           2019-08-29                6.500
# Cyrano, My Love                   0           2018-11-10                7.500
# Five Feet Apart            92600000           2019-03-14                8.271
# I Love My Dad                     0           2022-08-05                5.800
#
#                     details_vote_count  \
# title
# Hard Luck Love Song                 10
# Falling Inn Love                  1114
# Cyrano, My Love                    476
# Five Feet Apart                   5395
# I Love My Dad                       42
#
#                                                          details_genre  \
# title
# Hard Luck Love Song  [{'id': 10749, 'name': 'Romance'}, {'id': 1040...
# Falling Inn Love     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# Cyrano, My Love      [{'id': 35, 'name': 'Comedy'}, {'id': 36, 'nam...
# Five Feet Apart      [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# I Love My Dad                           [{'id': 35, 'name': 'Comedy'}]
#
#                                               details_spoken_languages  \
# title
# Hard Luck Love Song  [{'english_name': 'English', 'iso_639_1': 'en'...
# Falling Inn Love     [{'english_name': 'English', 'iso_639_1': 'en'...
# Cyrano, My Love      [{'english_name': 'French', 'iso_639_1': 'fr',...
# Five Feet Apart      [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# I Love My Dad        [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                           details_production_countries  \
# title
# Hard Luck Love Song  [{'iso_3166_1': 'US', 'name': 'United States o...
# Falling Inn Love     [{'iso_3166_1': 'US', 'name': 'United States o...
# Cyrano, My Love      [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...
# Five Feet Apart      [{'iso_3166_1': 'US', 'name': 'United States o...
# I Love My Dad        [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                                  details_genre_fixed  \
# title
# Hard Luck Love Song   10749 Romance 10402 Music 18 Drama 53 Thriller
# Falling Inn Love                             10749 Romance 35 Comedy
# Cyrano, My Love                                 35 Comedy 36 History
# Five Feet Apart                               10749 Romance 18 Drama
# I Love My Dad                                              35 Comedy
#
#                                         details_spoken_languages_fixed  \
# title
# Hard Luck Love Song              English en English Spanish es Español
# Falling Inn Love                                    English en English
# Cyrano, My Love                  French fr Français Russian ru Pусский
# Five Feet Apart       Spanish es Español English en English French ...
# I Love My Dad                                       English en English
#
#                      details_production_countries_fixed
# title
# Hard Luck Love Song         US United States of America
# Falling Inn Love            US United States of America
# Cyrano, My Love                    BE Belgium FR France
# Five Feet Apart             US United States of America
# I Love My Dad               US United States of America
#
# [5 rows x 46 columns]

# %%
# Drop "byline.person" column

combined_cleanup_df = combined_df2.drop(columns='byline.person', inplace=False)
combined_cleanup_df.columns
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.organization', 'adult',
#        'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'video', 'vote_average', 'vote_count',
#        'details_original_title', 'details_budget', 'details_original_language',
#        'details_homepage', 'details_overview', 'details_popularity',
#        'details_runtime', 'details_revenue', 'details_release_date',
#        'details_vote_average', 'details_vote_count', 'details_genre',
#        'details_spoken_languages', 'details_production_countries'],
#       dtype='object')

# %%
# Delete duplicate rows and reset index

#combined_cleanup_duplicates_df = combined_cleanup_df.drop_duplicates(keep='first')

combined_cleanup_duplicates_df = combined_cleanup_df.drop_duplicates(subset=['web_url', 'snippet', 'source', 'pub_date', 'word_count'], keep='first')
combined_cleanup_duplicates_df.shape
# Out:
# (11, 42)

# %%
# Export data to CSV without the index
combined_cleanup_duplicates_df.to_csv('output\combined.csv', encoding='utf-8')
